# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([-7.0,-4.0,-1.0,2.0,5.0,8.0,11.0,14.0])

# %%
y = np.array([3.0,6.0,9.0,12.0,15.0,18.0,21.0,24.0])

# %%
plt.scatter(x,y)

# %%
input_data = tf.constant(["bedroom","bathroom","garage"])
output_data = tf.constant([93400])
input_data, output_data
# Out:
# (<tf.Tensor: shape=(3,), dtype=string, numpy=array([b'bedroom', b'bathroom', b'garage'], dtype=object)>,
#  <tf.Tensor: shape=(1,), dtype=int32, numpy=array([93400], dtype=int32)>)

# %%
x[0],y[0]
# Out:
# (-7.0, 3.0)

# %%
tf.constant(x)
tf.constant(y)
x, y
# Out:
# (array([-7., -4., -1.,  2.,  5.,  8., 11., 14.]),
#  array([ 3.,  6.,  9., 12., 15., 18., 21., 24.]))

# %%
# Steps in modelling with tensorflow

# Set Random seed
tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
             optimizer=tf.keras.optimizers.SGD(),
             metrics=["mae"])

model.fit(x,y,epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 0s 387ms/step - loss: 11.5048 - mae: 11.5048
# Epoch 2/5
# 1/1 [==============================] - 0s 8ms/step - loss: 11.3723 - mae: 11.3723
# Epoch 3/5
# 1/1 [==============================] - 0s 3ms/step - loss: 11.2398 - mae: 11.2398
# Epoch 4/5
# 1/1 [==============================] - 0s 4ms/step - loss: 11.1073 - mae: 11.1073
# Epoch 5/5
# 1/1 [==============================] - 0s 6ms/step - loss: 10.9748 - mae: 10.9748

# %%
y_pred = model.predict([17.0])
y_pred
# Out:
# array([[12.716021]], dtype=float32)

# %%
# Improving our model
# Create the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

# %%
# Compile the model
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# %%
model.fit(x,y,epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 360ms/step - loss: 11.2219 - mae: 11.2219
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 11.0894 - mae: 11.0894
# Epoch 3/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.9569 - mae: 10.9569
# Epoch 4/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.8244 - mae: 10.8244
# Epoch 5/100
# 1/1 [==============================] - 0s 6ms/step - loss: 10.6919 - mae: 10.6919
# Epoch 6/100
# 1/1 [==============================] - 0s 7ms/step - loss: 10.5594 - mae: 10.5594
# Epoch 7/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.4269 - mae: 10.4269
# Epoch 8/100
# 1/1 [==============================] - 0s 5ms/step - loss: 10.2944 - mae: 10.2944
# Epoch 9/100
# 1/1 [==============================] - 0s 4ms/step - loss: 10.1619 - mae: 10.1619
# Epoch 10/100
# 1/1 [==============================] - 0s 5ms/step - loss: 10.0294 - mae: 10.0294
# Epoch 11/100
# ...

# %%
model.predict([17.0])
# Out:
# array([[29.739855]], dtype=float32)

# %%
# Improving our model
# Create the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, activation="relu"),
    tf.keras.layers.Dense(1)
])

# %%
# Compile a model
model.compile(loss="mae",
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
              metrics=["mae"])

# %%
# Fit the model
model.fit(x,y,epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 447ms/step - loss: 10.0210 - mae: 10.0210
# Epoch 2/100
# 1/1 [==============================] - 0s 5ms/step - loss: 9.9218 - mae: 9.9218
# Epoch 3/100
# 1/1 [==============================] - 0s 7ms/step - loss: 9.8215 - mae: 9.8215
# Epoch 4/100
# 1/1 [==============================] - 0s 9ms/step - loss: 9.7199 - mae: 9.7199
# Epoch 5/100
# 1/1 [==============================] - 0s 7ms/step - loss: 9.6172 - mae: 9.6172
# Epoch 6/100
# 1/1 [==============================] - 0s 7ms/step - loss: 9.5133 - mae: 9.5133
# Epoch 7/100
# 1/1 [==============================] - 0s 4ms/step - loss: 9.4082 - mae: 9.4082
# Epoch 8/100
# 1/1 [==============================] - 0s 4ms/step - loss: 9.3018 - mae: 9.3018
# Epoch 9/100
# 1/1 [==============================] - 0s 5ms/step - loss: 9.1941 - mae: 9.1941
# Epoch 10/100
# 1/1 [==============================] - 0s 3ms/step - loss: 9.0852 - mae: 9.0852
# Epoch 11/100
# ...

# %%
x,y
# Out:
# (array([-7., -4., -1.,  2.,  5.,  8., 11., 14.]),
#  array([ 3.,  6.,  9., 12., 15., 18., 21., 24.]))

# %%
model.predict([17.0])
# Out:
# array([[31.551876]], dtype=float32)

# %%
x = tf.range(-100,100,4)
x
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96], dtype=int32)>

# %%
y = x + 10
y
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y)

# %%
#  3 sets
x_train = x[:40]
y_train = y[:40]

# %%
x_test = x[40:]
y_test = y[40:]

# %%
# Visualizing the data
plt.figure(figsize=(10,7))
# Plot test data in green
plt.scatter(x_train, y_train, c="b", label="Training data")
# Plot test data in green
plt.scatter(x_test, y_test, c="g", label="Testing data")

# %%
# Building a neural network
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model.compile(loss = tf.keras.losses.mae,
             optimizer=tf.keras.optimizers.SGD(),
             metrics=["mae"])

model.fit(x_train, y_train,epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 8ms/step - loss: 10.5273 - mae: 10.5273
# Epoch 2/100
# 2/2 [==============================] - 0s 8ms/step - loss: 9.3906 - mae: 9.3906
# Epoch 3/100
# 2/2 [==============================] - 0s 12ms/step - loss: 7.6292 - mae: 7.6292
# Epoch 4/100
# 2/2 [==============================] - 0s 5ms/step - loss: 9.6859 - mae: 9.6859
# Epoch 5/100
# 2/2 [==============================] - 0s 8ms/step - loss: 11.0740 - mae: 11.0740
# Epoch 6/100
# 2/2 [==============================] - 0s 5ms/step - loss: 10.2264 - mae: 10.2264
# Epoch 7/100
# 2/2 [==============================] - 0s 10ms/step - loss: 9.2347 - mae: 9.2347
# Epoch 8/100
# 2/2 [==============================] - 0s 8ms/step - loss: 9.1547 - mae: 9.1547
# Epoch 9/100
# 2/2 [==============================] - 0s 11ms/step - loss: 11.7875 - mae: 11.7875
# Epoch 10/100
# 2/2 [==============================] - 0s 10ms/step - loss: 13.7172 - mae: 13.7172
# Epoch 11/100
# ...

# %%
# Visualize the model
tf.random.set_seed(42)

# %%
# Create a model (same as above)
model = tf.keras.Sequential([
    tf.keras.layers.Dense(2,input_shape=[1], name="input_layer"),
    tf.keras.layers.Dense(1,name="output_layer")
], name="model_1")


model.compile(loss = tf.keras.losses.mae,
             optimizer=tf.keras.optimizers.SGD(),
             metrics=["mae"])

model.fit(x_train, y_train,epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 3ms/step - loss: 28.1523 - mae: 28.1523
# Epoch 2/100
# 2/2 [==============================] - 0s 3ms/step - loss: 9.2143 - mae: 9.2143
# Epoch 3/100
# 2/2 [==============================] - 0s 5ms/step - loss: 17.6259 - mae: 17.6259
# Epoch 4/100
# 2/2 [==============================] - 0s 9ms/step - loss: 11.6141 - mae: 11.6141
# Epoch 5/100
# 2/2 [==============================] - 0s 5ms/step - loss: 12.4787 - mae: 12.4787
# Epoch 6/100
# 2/2 [==============================] - 0s 3ms/step - loss: 10.1186 - mae: 10.1186
# Epoch 7/100
# 2/2 [==============================] - 0s 4ms/step - loss: 10.9981 - mae: 10.9981
# Epoch 8/100
# 2/2 [==============================] - 0s 8ms/step - loss: 10.9666 - mae: 10.9666
# Epoch 9/100
# 2/2 [==============================] - 0s 8ms/step - loss: 39.2771 - mae: 39.2771
# Epoch 10/100
# 2/2 [==============================] - 0s 9ms/step - loss: 26.8218 - mae: 26.8218
# Epoch 11/100
# ...

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_layer (Dense)          (None, 2)                 4
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 3
# ...
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=100,verbose=0)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_layer (Dense)          (None, 2)                 4
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 3
# ...
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model=model, show_shapes=True)

# %%
# Visualizing the model's predictions
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[ 79.0591  ],
#        [ 84.108154],
#        [ 89.1572  ],
#        [ 94.20626 ],
#        [ 99.25531 ],
#        [104.304375],
#        [109.353424],
#        [114.402466],
#        [119.45153 ],
#        [124.50058 ]], dtype=float32)

# %%
y_test
# Out:
# <tf.Tensor: shape=(10,), dtype=int32, numpy=array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
def plot_predictions(train_data=x_train,
                     train_label = y_train,
                     test_data=x_test,
                    test_label=y_test,
                    predictions= y_pred):
    plt.figure(figsize=(10,7))
#     Plot training data in blue
    plt.scatter(train_data,train_label, c="b",label="Training data")
    #     Plot training data in green
    plt.scatter(test_data,test_label, c="g",label="Test data")
     #     Plot training data in green
    plt.scatter(test_data,predictions, c="r",label="Prediction")
#     Show the legend
    plt.legend();

# %%
plot_predictions(train_data=x_train,
                 train_label=y_train,
                 test_data=x_test,
                 test_label=y_test,
                 predictions=y_pred)

# %%
# Evaluate our model on the test
model.evaluate(x_test, y_test)
# Out:
# 1/1 [==============================] - 0s 203ms/step - loss: 13.7798 - mae: 13.7798
# [13.779840469360352, 13.779840469360352]

# %%
# Calculate the mean absolute error
tf.squeeze(y_pred)
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([ 79.0591  ,  84.108154,  89.1572  ,  94.20626 ,  99.25531 ,
#        104.304375, 109.353424, 114.402466, 119.45153 , 124.50058 ],
#       dtype=float32)>

# %%
y_test
# Out:
# <tf.Tensor: shape=(10,), dtype=int32, numpy=array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
mae = tf.metrics.mean_absolute_error(y_true=y_test,
                                    y_pred = tf.squeeze(y_pred))
mae
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=13.77984>

# %%
mae = tf.metrics.mean_squared_error(y_true=y_test,
                                    y_pred = tf.squeeze(y_pred))
mae
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=198.96323>

# %%
def mae(y_true,y_pred):
    return tf.metrics.mean_absolute_error(y_true=y_true,
                                          y_pred=tf.squeeze(y_pred))

def mse(y_true,y_pred):
    return tf.metrics.mean_squared_error(y_true=y_true,
                                          y_pred=tf.squeeze(y_pred))

# %%
# set random seed
tf.random.set_seed(42)

model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model_1.compile(loss=tf.keras.losses.mae,
               optimizer=tf.keras.optimizers.SGD(),
               metrics=["mae"])

# %%
model_1.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 3ms/step - loss: 15.9024 - mae: 15.9024
# Epoch 2/100
# 2/2 [==============================] - 0s 4ms/step - loss: 11.2837 - mae: 11.2837
# Epoch 3/100
# 2/2 [==============================] - 0s 6ms/step - loss: 11.1075 - mae: 11.1075
# Epoch 4/100
# 2/2 [==============================] - 0s 9ms/step - loss: 9.2990 - mae: 9.2990
# Epoch 5/100
# 2/2 [==============================] - 0s 3ms/step - loss: 10.1677 - mae: 10.1677
# Epoch 6/100
# 2/2 [==============================] - 0s 3ms/step - loss: 9.4303 - mae: 9.4303
# Epoch 7/100
# 2/2 [==============================] - 0s 12ms/step - loss: 8.5704 - mae: 8.5704
# Epoch 8/100
# 2/2 [==============================] - 0s 5ms/step - loss: 9.0442 - mae: 9.0442
# Epoch 9/100
# 2/2 [==============================] - 0s 7ms/step - loss: 18.7517 - mae: 18.7517
# Epoch 10/100
# 2/2 [==============================] - 0s 5ms/step - loss: 10.1142 - mae: 10.1142
# Epoch 11/100
# ...

# %%
y_preds_1 = model_1.predict(x_test)
plot_predictions(predictions=y_preds_1)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe7b1bb8550> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
mae_1 = mae(y_test, y_preds_1)
mse_1 = mse(y_test, y_preds_1)
mae_1, mse_1
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=18.745327>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=353.57336>)

# %%
# Build model 2
# 2 layers , trained for 100 epochs
tf.random.set_seed(42)

model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1),
    
])

model_2.compile(loss= tf.keras.losses.mae,
               optimizer = tf.keras.optimizers.SGD(),
               metrics=["mse"])

model_2.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 4ms/step - loss: 27.4058 - mse: 1084.1482
# Epoch 2/100
# 2/2 [==============================] - 0s 6ms/step - loss: 24.6339 - mse: 777.9203
# Epoch 3/100
# 2/2 [==============================] - 0s 5ms/step - loss: 29.8935 - mse: 1334.8953
# Epoch 4/100
# 2/2 [==============================] - 0s 10ms/step - loss: 27.4055 - mse: 1106.8033
# Epoch 5/100
# 2/2 [==============================] - 0s 4ms/step - loss: 14.9463 - mse: 281.1076
# Epoch 6/100
# 2/2 [==============================] - 0s 10ms/step - loss: 11.8819 - mse: 168.6621
# Epoch 7/100
# 2/2 [==============================] - 0s 4ms/step - loss: 11.1988 - mse: 151.3508
# Epoch 8/100
# 2/2 [==============================] - 0s 10ms/step - loss: 11.0910 - mse: 160.3745
# Epoch 9/100
# 2/2 [==============================] - 0s 4ms/step - loss: 40.4763 - mse: 2586.0088
# Epoch 10/100
# 2/2 [==============================] - 0s 5ms/step - loss: 27.8687 - mse: 1094.4380
# ...

# %%
y_preds_2 = model.predict(x_test)
plot_predictions(predictions=y_preds_2)

# %%
mae_2 = mae(y_test, y_preds_2)
mse_2 = mse(y_test, y_preds_2)

mae_2, mse_2
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=13.77984>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=198.96323>)

# %%
# Model 3
tf.random.set_seed(42)

model_3 = tf.keras.Sequential([
        tf.keras.layers.Dense(10),
        tf.keras.layers.Dense(1)
])
        

model_3.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=["mse"]
               )

# %%
model_3.fit(x_train,y_train,epochs=1000)
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 1s 5ms/step - loss: 27.4058 - mse: 1084.1482
# Epoch 2/1000
# 2/2 [==============================] - 0s 4ms/step - loss: 24.6339 - mse: 777.9203
# Epoch 3/1000
# 2/2 [==============================] - 0s 4ms/step - loss: 29.8935 - mse: 1334.8953
# Epoch 4/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 27.4055 - mse: 1106.8033
# Epoch 5/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 14.9463 - mse: 281.1076
# Epoch 6/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 11.8819 - mse: 168.6621
# Epoch 7/1000
# 2/2 [==============================] - 0s 16ms/step - loss: 11.1988 - mse: 151.3508
# Epoch 8/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 11.0910 - mse: 160.3745
# Epoch 9/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 40.4763 - mse: 2586.0088
# Epoch 10/1000
# ...

# %%
y_pred_3 = model.predict(x_test)
y_pred_3
# Out:
# array([[ 79.0591  ],
#        [ 84.108154],
#        [ 89.1572  ],
#        [ 94.20626 ],
#        [ 99.25531 ],
#        [104.304375],
#        [109.353424],
#        [114.402466],
#        [119.45153 ],
#        [124.50058 ]], dtype=float32)

# %%
plot_predictions(predictions=y_pred_3)

# %%
mae_3 = mae(y_test, y_pred_3)
mse_3 = mse(y_test, y_pred_3)

# %%
# Comparing the results of out experiments
import pandas as pd

model_results = [["model_1",mae_1.numpy(),mse_1.numpy()],
                 ["model_2",mae_2.numpy(),mse_2.numpy()],
                 ["model_3",mae_3.numpy(),mse_3.numpy()]]

all_results = pd.DataFrame(model_results, columns=["model","mae","mse"])
all_results
# Out:
#      model        mae         mse
# 0  model_1  18.745327  353.573364
# 1  model_2  13.779840  198.963226
# 2  model_3  13.779840  198.963226

# %%
# Saving our models
model_2.save("best_model_saved_format")
# Out:
# INFO:tensorflow:Assets written to: best_model_saved_format/assets

# %%
model_2.save("my_model_h5.h5")

# %%
saved_model =  tf.keras.models.load_model("best_model_saved_format")
saved_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 10)                20
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 11
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2_preds = model_2.predict(x_test)
saved_model =  tf.keras.models.load_model("best_model_saved_format")

model_2_preds == saved_model
# Out:
# WARNING:tensorflow:6 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe81155c820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False]])

# %%
mae(y_test, model_2_preds)

saved_model_pred = saved_model.predict(x_test)
mae(y_test, saved_model_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=3.19694>

# %%
mae(y_test, model_2_preds) == mae(y_test, saved_model_pred)
# Out:
# <tf.Tensor: shape=(), dtype=bool, numpy=True>

# %%
model_2_preds == saved_model_pred
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True]])

# %%
load_h5_model = tf.keras.models.load_model("my_model_h5.h5")

# %%
load_h5_model

# %%
h5_model_predict = load_h5_model.predict(x_test)

# %%
model_2_preds == h5_model_predict
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True]])
